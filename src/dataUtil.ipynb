# %%
from fractions import gcd
import midi
import os.path
import sys

# %% [markdown]
# # Class Music Pattern

# %%
class MusicPattern():
    """
    This class represents a musical pattern and provides
    method to convert it across midi, lisp and prim format
    """
    def __init__(self, midiFile=None):
        if midiFile is not None:
            self.read(midiFile)

    def read(self, midiFile):
        self.midiFile    = midiFile
        self.midiPattern = midi.read_midifile(midiFile)

        self.trackIdx = []
        self.channels = []
        for trackNum, midiTrack in enumerate(self.midiPattern):
            isTrack = False
            for midiEvent in midiTrack:
                if type(midiEvent) == midi.events.NoteOnEvent:
                    isTrack = True
                    self.channels.append(midiEvent.channel)
                    break
            if isTrack:
                self.trackIdx.append(trackNum)

        self.numTracks   = len(self.trackIdx)
        self.lispTracks  = []
        print "Loaded %s" % midiFile

    def midiToLisp(self):
        lispTracks = []
        for midiTrackId, midiTrack in enumerate(self.midiPattern):
            if midiTrackId not in self.trackIdx: continue

            lispTrack = []
            for eventNum, event in enumerate(midiTrack):
                if type(event)                 == midi.events.NoteOnEvent and \
                   type(midiTrack[eventNum+1]) == midi.events.NoteOffEvent:
                    # If not a silence, add (pitch, dur)
                    if event.tick == 0:
                        pitch  = event.data[0]
                        dur    = midiTrack[eventNum+1].tick - event.tick
                        notes  = [(pitch, dur)]

                    # Otherwise add silence and next note
                    else:
                        notes = [("silence", event.tick)]
                        pitch = midiTrack[eventNum+1].data[0]
                        dur   = midiTrack[eventNum+1].tick
                        notes += [(pitch, dur)]

                    # Add generated notes to track
                    lispTrack += notes
            lispTracks.append(lispTrack)
        self.lispTracks = lispTracks

    def lispToPrim(self):
        self.primTracks, self.rythmUnits = [], []
        for lispTrackNum, lispTrack in enumerate(self.lispTracks):
            min_duration = 0
            durations = [lispTrack[i][1] for i in range(len(lispTrack))]
            self.rythmUnits.append(reduce(gcd, durations))

            for noteNum, note in enumerate(lispTrack):
                assert(note[1] % self.rythmUnits[-1] == 0)

            primTrack = [(note[0],True) if (i < note[1]/self.rythmUnits[-1] - 1) else (note[0],False) \
                              for note in lispTrack for i in range(note[1]/self.rythmUnits[-1])]
            self.primTracks.append(primTrack)

    def primToLisp(self):
        lispTracks = []
        for trackNum, primTrack in enumerate(self.primTracks):
            lispTrack = []
            if primTrack:
                i = 0
                while i < len(primTrack):
                    note = [primTrack[i][0], self.rythmUnits[trackNum]]
                    while primTrack[i][1]:
                        note[1] += self.rythmUnits[trackNum]
                        i += 1
                    i+=1
                    lispTrack.append(tuple(note))
            lispTracks.append(lispTrack)

        self.reconstructedTracks = lispTracks

    def lispToMidi(self, lispTracks=None):
        midiPatternOut = midi.containers.Pattern()
        if self.midiPattern is not None:
            # copy pattern metadata
            midiPatternOut.format     = self.midiPattern.format
            midiPatternOut.resolution = self.midiPattern.resolution

        # Create tracks
        if lispTracks is None: lispTracks = self.reconstructedTracks
        midiTracksOut = []
        for trackNum, _ in enumerate(self.midiPattern):
            if trackNum in self.trackIdx:
                midiPatternOut.append(midi.containers.Track())
                midiTracksOut.append([])
            else:
                midiPatternOut.append(self.midiPattern[trackNum])
            

        # Generate tracks' NoteOnEvents and NoteOffEvents
        for lispTrackId, lispTrack in enumerate(lispTracks):
            noteNumAfterSilence = -1
            for noteNum, note in enumerate(lispTrack):
                if note[0] == "silence":
                    NoteOnEvent = midi.events.NoteOnEvent(tick=note[1], \
                                                          channel=self.channels[lispTrackId], \
                                                          data=[lispTrack[noteNum+1][0], 80])

                    NoteOffEvent = midi.events.NoteOffEvent(tick=lispTrack[noteNum+1][1], \
                                                            channel=self.channels[lispTrackId], \
                                                            data=[lispTrack[noteNum+1][0], 0])

                    midiTracksOut[lispTrackId] += [NoteOnEvent, NoteOffEvent]
                    noteNumAfterSilence = noteNum+1

                elif noteNum != noteNumAfterSilence:
                    NoteOnEvent = midi.events.NoteOnEvent(tick=0, \
                                                          channel=self.channels[lispTrackId], \
                                                          data=[note[0], 80])
                    NoteOffEvent = midi.events.NoteOffEvent(tick=note[1], \
                                                            channel=self.channels[lispTrackId], \
                                                            data=[note[0], 0])
                    midiTracksOut[lispTrackId] += [NoteOnEvent, NoteOffEvent]

        # Add tracks to midiPattern
        realTrackIdx = -1
        if self.midiPattern is not None:
            for midiTrackId, midiTrack in enumerate(self.midiPattern):
                if midiTrackId not in self.trackIdx: continue
                realTrackIdx+= 1
                for eventNum, event in enumerate(midiTrack):
                    if type(event) not in [midi.events.NoteOnEvent, midi.events.NoteOffEvent]:
                        midiPatternOut[midiTrackId].append(event)
                    elif type(midiTrack[eventNum-1]) not in \
                    [midi.events.NoteOnEvent, midi.events.NoteOffEvent]:
                        midiPatternOut[midiTrackId].extend(midiTracksOut[realTrackIdx])

        else:
            for midiTrackId, midiTrack in enumerate(midiTracksOut):
                midiPatternOut[midiTrackId].extend(midiTracksOut[midiTrackId])
            midiPatternOut[0].append(midi.EndOfTrackEvent(tick=1))
        
        self.midiPatternOut = midiPatternOut

        # Write file
    def write(self, fileName=None):
        if fileName is None:
            i = 1
            while os.path.isfile(self.midiFile[0:-4] + str(i) + ".mid"):
                i += 1
            fileName = self.midiFile[0:-4] + str(i) + ".mid"

        midi.write_midifile(fileName, self.midiPatternOut)
        print "Wrote %s" % fileName
        print self.midiPatternOut == self.midiPattern

    def window(self, window, trackNum=0):
        (start, end) = window
        assert(0 <= trackNum and trackNum < self.numTracks)
        primTrack = self.primTracks[trackNum]
        assert (2 <= start and end < len(primTrack)-2)

        windowedTrack = list(primTrack)
        for i in range(start, end+1):
            windowedTrack[i] = (None, None)
        return windowedTrack

    def getCorrupt(self, window, trackNum=0):
        return self.rythmUnits[trackNum], self.window(window, trackNum)
    
    def getMidiPatternOut(self):
        return self.midiPatternOut

# %%
midi_file = "/Users/robin/Desktop/CS221_projet/Open_MIDI_file/chor_armure.mid"
mypattern = MusicPattern(midi_file)
mypattern.midiToLisp()
mypattern.lispToPrim()
mypattern.primToLisp()
mypattern.lispToMidi()
mypattern.write()
# Out:
# Loaded /Users/robin/Desktop/CS221_projet/Open_MIDI_file/chor_armure.mid
# Wrote /Users/robin/Desktop/CS221_projet/Open_MIDI_file/chor_armure6.mid
# False
# original
# midi.Pattern(format=1, resolution=384, tracks=\
# [midi.Track(\
#   [midi.TimeSignatureEvent(tick=0, data=[2, 2, 96, 8]),
#    midi.SequencerSpecificEvent(tick=0, data=[0, 0, 65]),
#    midi.SetTempoEvent(tick=0, data=[10, 44, 42]),
#    midi.SetTempoEvent(tick=153600, data=[10, 44, 42]),
#    midi.SetTempoEvent(tick=28, data=[10, 73, 109]),
#    midi.SetTempoEvent(tick=28, data=[10, 103, 90]),
#    midi.SetTempoEvent(tick=28, data=[10, 133, 247]),
#    midi.SetTempoEvent(tick=28, data=[10, 165, 74]),
#    midi.SetTempoEvent(tick=28, data=[10, 197, 90]),
#    midi.SetTempoEvent(tick=28, data=[10, 230, 45]),
#    midi.SetTempoEvent(tick=28, data=[11, 7, 203]),
#    midi.SetTempoEvent(tick=28, data=[11, 42, 59]),
#    midi.SetTempoEvent(tick=28, data=[11, 77, 132]),
#    midi.SetTempoEvent(tick=28, data=[11, 113, 176]),
#    midi.SetTempoEvent(tick=28, data=[11, 150, 197]),
#    midi.SetTempoEvent(tick=28, data=[11, 188, 206]),
#    midi.SetTempoEvent(tick=28, data=[11, 227, 212]),
#    midi.SetTempoEvent(tick=28, data=[12, 11, 225]),
#    midi.SetTempoEvent(tick=28, data=[12, 53, 0]),
#    midi.SetTempoEvent(tick=28, data=[12, 95, 58]),
#    midi.SetTempoEvent(tick=28, data=[12, 138, 157]),
#    midi.SetTempoEvent(tick=28, data=[12, 183, 53]),
#    midi.SetTempoEvent(tick=28, data=[12, 229, 14]),
#    midi.SetTempoEvent(tick=28, data=[13, 20, 54]),
#    midi.SetTempoEvent(tick=28, data=[13, 68, 189]),
#    midi.SetTempoEvent(tick=28, data=[13, 118, 176]),
#    midi.SetTempoEvent(tick=28, data=[13, 170, 34]),
#    midi.SetTempoEvent(tick=28, data=[13, 223, 34]),
#    midi.SetTempoEvent(tick=28, data=[14, 21, 196]),
#    midi.SetTempoEvent(tick=28, data=[14, 78, 28]),
#    midi.SetTempoEvent(tick=28, data=[14, 136, 60]),
#    midi.SetTempoEvent(tick=28, data=[14, 196, 61]),
#    midi.SetTempoEvent(tick=28, data=[15, 2, 54]),
#    midi.SetTempoEvent(tick=28, data=[15, 66, 64]),
#    midi.SetTempoEvent(tick=28, data=[15, 132, 117]),
#    midi.SetTempoEvent(tick=28, data=[15, 200, 242]),
#    midi.SetTempoEvent(tick=28, data=[16, 15, 215]),
#    midi.SetTempoEvent(tick=28, data=[16, 89, 68]),
#    midi.SetTempoEvent(tick=28, data=[16, 165, 93]),
#    midi.SetTempoEvent(tick=28, data=[16, 244, 71]),
#    midi.SetTempoEvent(tick=28, data=[17, 70, 43]),
#    midi.SetTempoEvent(tick=28, data=[17, 155, 54]),
#    midi.SetTempoEvent(tick=28, data=[17, 243, 150]),
#    midi.SetTempoEvent(tick=28, data=[18, 79, 128]),
#    midi.SetTempoEvent(tick=28, data=[18, 175, 41]),
#    midi.SetTempoEvent(tick=28, data=[19, 18, 208]),
#    midi.SetTempoEvent(tick=28, data=[19, 122, 179]),
#    midi.SetTempoEvent(tick=28, data=[19, 231, 27]),
#    midi.SetTempoEvent(tick=28, data=[20, 88, 85]),
#    midi.SetTempoEvent(tick=28, data=[20, 206, 180]),
#    midi.SetTempoEvent(tick=28, data=[21, 74, 148]),
#    midi.SetTempoEvent(tick=28, data=[21, 204, 91]),
#    midi.SetTempoEvent(tick=28, data=[22, 84, 118]),
#    midi.SetTempoEvent(tick=28, data=[22, 227, 96]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.TrackNameEvent(tick=0, text='Tromba I', data=[84, 114, 111, 109, 98, 97, 32, 73]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[0, 0]),
#    midi.ProgramChangeEvent(tick=0, channel=0, data=[56]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[7, 127]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[10, 61]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[91, 127]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[93, 127]),
#    midi.KeySignatureEvent(tick=0, data=[2, 0]),
#    midi.NoteOnEvent(tick=768, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=384, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=192, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=256, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=256, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=352, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=384, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=192, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=256, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=256, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=352, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[76, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[76, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[86, 100]),
#    midi.NoteOffEvent(tick=512, channel=0, data=[86, 64]),
#    midi.NoteOnEvent(tick=64, channel=0, data=[85, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[85, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[85, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[85, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=768, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=768, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[73, 64]),
#    midi.NoteOnEvent(tick=4992, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=512, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=64, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=512, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=64, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=384, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=6240, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=512, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=64, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=256, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=256, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=384, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=960, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=960, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[86, 100]),
#    midi.NoteOffEvent(tick=512, channel=0, data=[86, 64]),
#    midi.NoteOnEvent(tick=64, channel=0, data=[85, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[85, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[85, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[85, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=14208, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[85, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[85, 64]),
#    midi.NoteOnEvent(tick=192, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=192, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=1920, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[85, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[85, 64]),
#    midi.NoteOnEvent(tick=192, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=192, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=1536, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=768, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=672, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[85, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[85, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[86, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[86, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[85, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[85, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=768, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=37632, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=384, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=192, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=256, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=256, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=352, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=384, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=4704, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=512, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=64, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=256, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=256, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=384, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=960, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=960, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=576, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=576, channel=0, data=[86, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[86, 64]),
#    midi.NoteOnEvent(tick=576, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=576, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=3072, channel=0, data=[79, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[79, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[78, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[79, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[78, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[76, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[74, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=960, channel=0, data=[81, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[81, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=12288, channel=0, data=[66, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[66, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[66, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[66, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=384, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=192, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=256, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=256, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=352, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=384, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=192, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=256, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=256, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=352, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[69, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[83, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[76, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[76, 100]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=192, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[80, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=96, channel=0, data=[74, 100]),
#    midi.NoteOffEvent(tick=96, channel=0, data=[74, 64]),
# ...
#    midi.NoteOnEvent(tick=0, channel=8, data=[50, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[50, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[38, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[38, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[42, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[42, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[45, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[45, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[50, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[50, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[38, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[38, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[50, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[50, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[48, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[48, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[47, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[47, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[52, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[52, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[48, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[48, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[50, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[50, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[43, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[43, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[45, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[45, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[47, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[47, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[45, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[45, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[44, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[44, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[42, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[42, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[44, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[44, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[40, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[40, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[45, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[45, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[57, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[57, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[55, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[55, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[54, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[54, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[52, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[52, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[50, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[50, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[49, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[49, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[47, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[47, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[49, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[49, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[52, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[52, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[49, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[49, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[45, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[45, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[50, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[50, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[38, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[38, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[50, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[50, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[43, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[43, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[50, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[50, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[38, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[38, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[42, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[42, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[47, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[47, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[43, 80]),
#    midi.NoteOffEvent(tick=384, channel=8, data=[43, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[45, 80]),
#    midi.NoteOffEvent(tick=384, channel=8, data=[45, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[50, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[50, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[49, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[49, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[47, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[47, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[45, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[45, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[43, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[43, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[42, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[42, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[40, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[40, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[38, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[38, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[62, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[62, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[61, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[61, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[59, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[59, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[62, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[62, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[61, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[61, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[59, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[59, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[57, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[57, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[55, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[55, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[54, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[54, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[52, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[52, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[50, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[50, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[47, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[47, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[43, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[43, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[45, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[45, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[38, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[38, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[40, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[40, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[42, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[42, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[43, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[43, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[45, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[45, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[47, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[47, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[49, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[49, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[50, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[50, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[62, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[62, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[61, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[61, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[57, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[57, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[62, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[62, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[61, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[61, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[59, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[59, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[57, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[57, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[55, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[55, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[54, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[54, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[52, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[52, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[50, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[50, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[47, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[47, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[43, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[43, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[45, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[45, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[38, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[38, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[40, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[40, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[42, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[42, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[43, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[43, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[45, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[45, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[47, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[47, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[49, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[49, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[50, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[50, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[62, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[62, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[59, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[59, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[54, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[54, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[56, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[56, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[52, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[52, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[56, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[56, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[59, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[59, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[49, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[49, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[61, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[61, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[57, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[57, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[52, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[52, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[54, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[54, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[42, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[42, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[54, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[54, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[57, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[57, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[47, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[47, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[59, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[59, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[61, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[61, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[59, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[59, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[57, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[57, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[56, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[56, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[54, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[54, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[56, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[56, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[57, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[57, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[59, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[59, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[57, 80]),
#    midi.NoteOffEvent(tick=96, channel=8, data=[57, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[56, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[56, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[52, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[52, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[57, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[57, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[61, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[61, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[64, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[64, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[52, 80]),
#    midi.NoteOffEvent(tick=192, channel=8, data=[52, 0]),
#    midi.NoteOnEvent(tick=0, channel=8, data=[57, 80]),
#    midi.NoteOffEvent(tick=768, channel=8, data=[57, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.ControlChangeEvent(tick=0, channel=5, data=[0, 0]),
#    midi.ProgramChangeEvent(tick=0, channel=5, data=[65]),
#    midi.ControlChangeEvent(tick=0, channel=5, data=[7, 127]),
#    midi.ControlChangeEvent(tick=0, channel=5, data=[10, 62]),
#    midi.ControlChangeEvent(tick=0, channel=5, data=[91, 127]),
#    midi.ControlChangeEvent(tick=0, channel=5, data=[93, 127]),
#    midi.KeySignatureEvent(tick=0, data=[0, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.ControlChangeEvent(tick=0, channel=6, data=[0, 0]),
#    midi.ProgramChangeEvent(tick=0, channel=6, data=[66]),
#    midi.ControlChangeEvent(tick=0, channel=6, data=[7, 127]),
#    midi.ControlChangeEvent(tick=0, channel=6, data=[10, 64]),
#    midi.ControlChangeEvent(tick=0, channel=6, data=[91, 127]),
#    midi.KeySignatureEvent(tick=0, data=[0, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.ControlChangeEvent(tick=0, channel=7, data=[0, 0]),
#    midi.ProgramChangeEvent(tick=0, channel=7, data=[67]),
#    midi.ControlChangeEvent(tick=0, channel=7, data=[7, 127]),
#    midi.ControlChangeEvent(tick=0, channel=7, data=[10, 62]),
#    midi.ControlChangeEvent(tick=0, channel=7, data=[91, 127]),
#    midi.KeySignatureEvent(tick=0, data=[0, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.ControlChangeEvent(tick=0, channel=8, data=[0, 0]),
#    midi.ProgramChangeEvent(tick=0, channel=8, data=[19]),
#    midi.ControlChangeEvent(tick=0, channel=8, data=[7, 110]),
#    midi.ControlChangeEvent(tick=0, channel=8, data=[10, 63]),
#    midi.ControlChangeEvent(tick=0, channel=8, data=[91, 127]),
#    midi.ControlChangeEvent(tick=0, channel=8, data=[93, 127]),
#    midi.KeySignatureEvent(tick=0, data=[0, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])])])

# %% [markdown]
# # Class Bach Chorale

# %%
class BachChorale(MusicPattern):
    """
    This class represents a choral from the Bach dataset
    (https://archive.ics.uci.edu/ml/datasets/Bach+Chorales)
    It provides methods to read from disk and write as .mid
    """

    def __init__(self, choraleFile, choraleNum):
        """
        This constructor loads the choraleNum th chorale
        from the choraleFile file and stores the pitches
        and durations into the self.notes variable
        """
        self.choraleFile = choraleFile
        self.choraleNum  = ((int(choraleNum)-1) % 100) + 1
        self.features    = ["pitch", "dur"]
        self.numTracks   = 1
        self.lispTracks  = [[]]
        self.midiPattern = None

        with open(self.choraleFile, 'r') as f:
            line = f.readlines()[2*(self.choraleNum-1)]
            choraleIdEndPosition = line.find('(', 1)
            self.choraleId = int(line[1:choraleIdEndPosition-1])

            N = len(self.features)
            featurePosition = line.find(self.features[0], 0)
            valueEndPosition = line.find(')', featurePosition)
            while featurePosition >= 0:
                note = []
                for i, feature in enumerate(self.features):
                    val = int(line[(featurePosition+len(feature)+1):valueEndPosition])
                    if feature == "dur": val *= 64
                    note += [val]

                    featurePosition = line.find(self.features[(i+1) % N], valueEndPosition)
                    valueEndPosition = line.find(')', featurePosition)
                self.lispTracks[0] += [tuple(note)]

    def __repr__(self):
        """
        Displays chorale metadata and notes
        """
        ret = "Bach Chorale %d (line %d in file %s)\n" % \
        (self.choraleId, 2*self.choraleNum + 1, self.choraleFile)
        ret += "pitch   dur\n"
        for note in self.lispTracks[0]:
            ret += "   %2d    %2d\n" % note
        return ret
